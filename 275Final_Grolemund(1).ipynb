# %% [markdown]
# # Initial Data Downloads
# Read the CSV, get the columns from it that we need

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/KevinGreatness/MovieRecommender/refs/heads/main/2025_movies_dataset.csv')
# Trim the panda
movies_df = df[['Title', 'Duration', 'Rating', 'description', 'Movie Link', 'stars', 'genres']]
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Clean the data
# 1.   Drop rows that have na values
# 2.   Drop movies with ratings under 5
# 3.   Remove the index number that comes with every movie title

# %%
movies_df = movies_df.dropna()
movies_df = movies_df.reset_index(drop=True)
# Drop movies that are poorly rated
for i, row in movies_df.iterrows():
  rating = float(row['Rating'])
  if rating < 5:
    movies_df.drop(i, inplace=True)
movies_df = movies_df.reset_index(drop=True)

import re

for i, row in movies_df.iterrows():
 title = str(row['Title'])
 # Only want to remove the index number in the title
 # Had to be careful here because some movie titles are purely integer numbers
 # Only want to remove FIRST num and the period
 title = re.sub(r'^\d+\s*', '', title)
 title = re.sub(r'\.', '', title)
 title = title.strip()
 movies_df.at[i, 'Title'] = title

movies_df
# Out:
#                                                  Title Duration  Rating  \
# 0                     Captain America: Brave New World   1h 58m     5.9
# 1                                              Dog Man   1h 29m     6.3
# 2                                     One of Them Days   1h 37m     6.6
# 3                                            Mickey 17   2h 17m     7.0
# 4                                           The Monkey   1h 38m     6.3
# 5                              Den of Thieves: Pantera   2h 24m     6.3
# 6                                           Heart Eyes   1h 37m     6.1
# 7                                          Flight Risk   1h 31m     5.3
# 8                                            Companion   1h 37m     7.0
# 9                                             Wolf Man   1h 43m     5.6
# 10                                         Last Breath   1h 33m     6.6
# 11                                            Ne Zha 2   2h 23m     8.2
# 12                                           Novocaine   1h 50m     6.8
# 13                                           Black Bag   1h 33m     7.3
# 14                                          Love Hurts   1h 23m     5.2
# 15                               Becoming Led Zeppelin    2h 2m     7.8
# 16                                 The Unbreakable Boy   1h 49m     5.7
# 17                                     The Last Supper   1h 54m     6.1
# 18                                             Chhaava   2h 41m     7.8
# 19                                    The Alto Knights    2h 3m     5.9
# 20                                       Rule Breakers       2h     7.4
# 21                            Detective Chinatown 1900   2h 18m     6.1
# 22                                        Game Changer   2h 45m     5.5
# 23                                   In the Lost Lands   1h 41m     5.0
# 24                Creation of the Gods II: Demon Force   2h 25m     6.5
# 25                                                Opus   1h 44m     5.9
# 26                                      Green and Gold   1h 45m     7.2
# 27                                         Valiant One   1h 26m     5.1
# 28             Mobile Suit Gundam GQuuuuuuX: Beginning   1h 21m     7.1
# 29                                              Locked   1h 35m     6.4
# 30                                           October 8   1h 40m     6.7
# 31                                                 Ash   1h 35m     5.9
# 32          Legends of the Condor Heroes: The Gallants   2h 26m     6.8
# 33                     Peter Pan's Neverland Nightmare   1h 29m     5.9
# 34                                         Inheritance   1h 41m     5.6
# 35                                           Dark Nuns   1h 54m     5.5
# 36                                           The Actor   1h 38m     7.6
# 37                                          Borderline   1h 34m     5.3
# 38                                      Both Eyes Open   1h 40m     8.1
# 39                                      When I'm Ready   1h 47m     8.0
# 40                                   Prisoners of Fire   1h 30m    10.0
# 41                                  The Electric State    2h 5m     6.0
# 42                                            Together   1h 42m     7.2
# 43                                           The Gorge    2h 7m     6.7
# 49                                     ['Documentary']
# 50                        ['Action', 'Crime', 'Drama']
# 51                               ['Comedy', 'Romance']
# 52                              ['Horror', 'Thriller']
# 53   ['Docudrama', 'Period Drama', 'Political Drama...
# 54   ['Whodunnit', 'Action', 'Crime', 'Drama', 'Mys...
# 55       ['Whodunnit', 'Drama', 'Mystery', 'Thriller']
# 56           ['Crime', 'Drama', 'Mystery', 'Thriller']
# 57                                ['Action', 'Comedy']
# 58   ['Political Drama', 'Political Thriller', 'Dra...
# 59                              ['Action', 'Thriller']
# 60   ['Dark Comedy', 'Action', 'Comedy', 'Crime', '...
# 61                         ['Spy', 'Action', 'Comedy']
# 62                                        ['Thriller']
# 63                                        ['Thriller']
# 64                               ['Crime', 'Thriller']
# 65                      ['Comedy', 'Drama', 'Romance']
# 66   ['Computer Animation', 'Adventure', 'Animation...
# 67   ['Survival', 'Zombie Horror', 'Action', 'Horro...
# 68                                          ['Comedy']
# 69   ['Body Horror', 'Satire', 'Slasher Horror', 'C...
# 70                                     ['Documentary']
# 71                               ['Comedy', 'Romance']
# 72                                        ['Thriller']
# 73                     ['Comedy', 'Drama', 'Thriller']
# 74                                         ['Romance']
# 75                                           ['Drama']
# 76   ['Supernatural Fantasy', 'Action', 'Adventure'...
# 77                              ['Action', 'Thriller']
# 78                                 ['Comedy', 'Drama']
# 79                               ['Drama', 'Thriller']
# 80   ['Time Travel', 'Adventure', 'Sci-Fi', 'Thrill...
# 81                                           ['Drama']
# 82   ['Dark Comedy', 'Slasher Horror', 'Teen Comedy...
# 83   ['One-Person Army Action', 'Road Trip', 'Actio...
# 84   ['Police Procedural', 'Crime', 'Drama', 'Thril...
# 85   ['One-Person Army Action', 'Psychological Thri...
# 86                                           ['Music']
# 87                                ['Action', 'Comedy']
# 88       ['Quirky Comedy', 'Comedy', 'Drama', 'Music']
# 89                                          ['Comedy']
# 90                            ['Crime', 'Documentary']
# 91   ['Adult Animation', 'Anime', 'Dark Fantasy', '...
# 92                                  ['Crime', 'Drama']
# 93                                 ['Comedy', 'Drama']
# 94                     ['Docudrama', 'Crime', 'Drama']
# 95   ['Teen Fantasy', 'Adventure', 'Family', 'Fanta...
# 96   ['Action', 'Crime', 'Drama', 'Mystery', 'Thril...
# 97                           ['Period Drama', 'Drama']
# 98                                          ['Action']
# 99                                           ['Drama']
# 100                     ['Comedy', 'Drama', 'Romance']
# 101                               ['Drama', 'Romance']
# 102              ['Stand-Up', 'Comedy', 'Documentary']
# 103     ['Action', 'Adventure', 'Romance', 'Thriller']
# 104                     ['Comedy', 'Drama', 'Romance']
# 105                      ['Comedy', 'Drama', 'Sci-Fi']
# 106  ['Action Epic', 'Cyber Thriller', 'Gun Fu', 'O...
# 107                       ['Comedy', 'Crime', 'Drama']
# 108                    ['Action', 'Crime', 'Thriller']
# 109  ['Docudrama', 'Period Drama', 'Showbiz Drama',...
# 110                             ['Horror', 'Thriller']
# 111                                         ['Comedy']
# 112                                         ['Comedy']
# 113                     ['Crime', 'Drama', 'Thriller']
# 114                    ['Action', 'Comedy', 'Romance']
# 115                    ['Biography', 'Drama', 'Music']
# 116                                    ['Documentary']
# 117                     ['Comedy', 'Drama', 'Fantasy']
# 118                                ['Comedy', 'Drama']
# 119                                         ['Comedy']
# 120  ['Action', 'Horror', 'Mystery', 'Sci-Fi', 'Thr...
# 121                                          ['Drama']
# 122                             ['Horror', 'Thriller']
# 123                               ['Drama', 'Romance']
# 124                                ['Comedy', 'Drama']
# 125                        ['Action', 'Comedy', 'War']
# 126              ['Stand-Up', 'Comedy', 'Documentary']
# 127                                          ['Drama']
# 128                                         ['Comedy']
# 129                   ['Biography', 'Comedy', 'Drama']
# 130                                       ['Thriller']
# 131                             ['Horror', 'Thriller']
# 132                   ['Drama', 'Romance', 'Thriller']
# 133                                          ['Drama']
# 134        ['Action', 'Documentary', 'Drama', 'Sport']
# 135                   ['Action', 'Adventure', 'Drama']
# 136                                          ['Drama']
# 137                                 ['Crime', 'Drama']
# 138                                          ['Drama']
# 139          ['Action', 'Comedy', 'Crime', 'Thriller']
# 140                                         ['Comedy']
# 141                                          ['Drama']
# 142                              ['Action', 'Musical']
# 143           ['Romantic Comedy', 'Comedy', 'Romance']
# 144                               ['Comedy', 'Horror']
# 145                              ['Comedy', 'Romance']
# 146     ['Action', 'Adventure', 'Animation', 'Family']
# 147                              ['Comedy', 'Romance']
# 148                                          ['Crime']
# 149  ['Political Drama', 'Prison Drama', 'Drama', '...
# 150                                       ['Thriller']
# 151                    ['Action', 'Drama', 'Thriller']
# 152                                          ['Drama']
# 153                                         ['Comedy']
# 154                                 ['Drama', 'Music']
# 155                                          ['Drama']
# 156                              ['Comedy', 'Romance']
# 157                                         ['Comedy']
# 158  ['Psychological Drama', 'Psychological Thrille...
# 159                               ['Comedy', 'Horror']
# 160                              ['Drama', 'Thriller']
# 161                                          ['Drama']
# 162                              ['Drama', 'Thriller']
# 163                    ['Drama', 'Horror', 'Thriller']
# 164                                   ['Drama', 'War']
# 165                                ['Comedy', 'Drama']
# 166                                          ['Drama']
# 167  ['Psychological Thriller', 'Drama', 'Mystery',...
# 168                                          ['Drama']
# 169                                          ['Drama']
# 170                  ['Crime', 'Documentary', 'Drama']
# 171                                          ['Drama']
# 172                  ['Horror', 'Mystery', 'Thriller']
# 173                                         ['Comedy']
# 174            ['Comedy', 'Drama', 'Horror', 'Sci-Fi']
# 175                   ['Horror', 'Sci-Fi', 'Thriller']
# 176                                         ['Horror']
# 177         ['Action', 'Comedy', 'Horror', 'Thriller']
# 178                                          ['Drama']
# 179                                          ['Drama']
# 180                                    ['Documentary']
# 181                                          ['Drama']
# 182                                         ['Comedy']
# 183                                          ['Drama']
# 184                                        ['Western']
# 185                    ['Anime', 'Animation', 'Music']
# 186                               ['Comedy', 'Family']
# 187  ['Action', 'Drama', 'Horror', 'Sci-Fi', 'Thril...
# 188                              ['Comedy', 'Romance']
# 189                     ['Crime', 'Drama', 'Thriller']
# 190                   ['Comedy', 'Horror', 'Thriller']
# 191                                          ['Drama']
# 192                                         ['Action']
# 193                   ['Drama', 'Mystery', 'Thriller']
# 194       ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']
# 195                  ['Fantasy', 'Horror', 'Thriller']
# 196                                          ['Drama']
# 197                                          ['Drama']
# 198                                          ['Drama']
# 199                    ['Action', 'Crime', 'Thriller']
# 200                                          ['Drama']
# 201                                ['Action', 'Drama']
# 202                                         ['Comedy']
# 203                                          ['Drama']
# 204                             ['Horror', 'Thriller']
# 205                                    ['Documentary']
# 206                                          ['Drama']
# 207                                         ['Comedy']
# 208                           ['Documentary', 'Music']
# 209                                                 []
# 210                                         ['Action']
# 211                               ['Comedy', 'Horror']
# 212                                          ['Drama']
# 213                    ['Comedy', 'Family', 'Romance']
# 214                             ['Horror', 'Thriller']
# 215  ['Music Documentary', 'Biography', 'Documentar...
# 216                                ['Comedy', 'Drama']
# 217                                          ['Drama']
# 218                                         ['Comedy']
# 219  ['One-Person Army Action', 'Parody', 'Action',...
# 220                               ['Drama', 'Romance']
# 221   ['Docudrama', 'Adventure', 'Biography', 'Drama']
# 222                                          ['Drama']
# 223                                          ['Drama']
# 224                       ['Biography', 'Documentary']
# 225                                        ['Romance']
# 226          ['Crime', 'Drama', 'Mystery', 'Thriller']
# 227  ['Feel-Good Romance', 'Romantic Comedy', 'Show...
# 228                                         ['Action']
# 229                                         ['Family']
# 230                                ['Comedy', 'Drama']
# 231                                          ['Drama']
# 232                                          ['Drama']
# 233                          ['Dark Comedy', 'Comedy']
# 234  ['Period Drama', 'Biography', 'Drama', 'Histor...
# 235                     ['Comedy', 'Drama', 'Romance']
# 236      ['Action', 'Adventure', 'Fantasy', 'Mystery']
# 237                                ['Drama', 'Sci-Fi']
# 238                              ['Drama', 'Thriller']
# 239                              ['Drama', 'Thriller']
# 240  ['Comedy', 'Horror', 'Romance', 'Sci-Fi', 'Thr...
# 241   ['Fairy Tale', 'Adventure', 'Family', 'Fantasy']
# 242                                ['Comedy', 'Drama']
# 243                     ['Action', 'Drama', 'Romance']
# 244                                          ['Drama']
# 245                                          ['Drama']
# 246                                ['Comedy', 'Drama']
# 247                                       ['Thriller']
# 248  ['Anime', 'Adventure', 'Animation', 'Comedy', ...
# 249                                    ['Documentary']
# 250                       ['Comedy', 'Crime', 'Drama']
# 251  ['Buddy Comedy', 'Supernatural Fantasy', 'Supe...
# 252                                          ['Drama']
# 253                                    ['Documentary']
# 254                              ['Drama', 'Thriller']
# 255                           ['Documentary', 'Sport']
# 256                                          ['Drama']
# 257                              ['Drama', 'Thriller']
# 258                                         ['Comedy']
# 259                     ['Drama', 'Horror', 'Mystery']
# 260  ['Drama', 'Horror', 'Mystery', 'Sci-Fi', 'Thri...
# 261                                    ['Documentary']
# 262                                         ['Comedy']
# 263  ['Folk Horror', 'Mountain Adventure', 'Adventu...
# 264                                         ['Comedy']
# 265                                       ['Thriller']
# 266                   ['Drama', 'Mystery', 'Thriller']
# 267                                        ['Romance']
# 268                              ['Comedy', 'Romance']
# 269                             ['Comedy', 'Thriller']
# 270                                          ['Drama']
# 271                                    ['Documentary']
# 272     ['Biography', 'Crime', 'Documentary', 'Music']
# 273                                        ['Romance']
# 274                               ['Drama', 'Romance']
# 275                                         ['Comedy']
# 276                                      ['Biography']
# 277                             ['Sci-Fi', 'Thriller']
# 278                                ['Drama', 'Family']
# 279                             ['Sci-Fi', 'Thriller']
# 280                                         ['Horror']
# 281  ['Buddy Comedy', 'Romantic Comedy', 'Comedy', ...
# 282                                          ['Drama']
# 283                                       ['Thriller']
# 284                                          ['Drama']
# 285                                          ['Drama']
# 286                                    ['Documentary']
# 287                                         ['Family']
# 288                    ['Comedy', 'Drama', 'Thriller']
# 289                               ['Comedy', 'Horror']
# 290              ['Period Drama', 'Drama', 'Thriller']
# 291                                        ['Romance']
# 292                                          ['Drama']
# 293    ['Biography', 'Documentary', 'Family', 'Music']
# 294                               ['Action', 'Comedy']
# 295                                          ['Drama']
# 296                                          ['Drama']
# 297                                          ['Drama']
# 298                                          ['Drama']
# 299                    ['Biography', 'Crime', 'Drama']
# 300                                          ['Drama']
# 301  ['Dystopian Sci-Fi', 'Adventure', 'Drama', 'Fa...
# 302                                ['Comedy', 'Drama']
# 303                                         ['Comedy']
# 304                                        ['Romance']
# 305                                          ['Drama']
# 306          ['Action', 'Drama', 'Horror', 'Thriller']
# 307                                          ['Music']
# 308                                         ['Horror']
# 309                                    ['Documentary']
# 310                                          ['Drama']
# 311                                ['Drama', 'Horror']
# 312                                       ['Thriller']
# 313                                          ['Drama']
# 314                      ['Comedy', 'Drama', 'Sci-Fi']
# 315                                         ['Horror']

# %% [markdown]
# # More Data cleaning
# Remove improperly formatted data
#
# Remove the spaces between actors names (We only want to match Harrison Ford exactly, we dont want to match every Harrison and every Ford)
#
# 1.   Remove improperly formatted data
# 2.   Remove the spaces between actors names (We only want to match Harrison Ford exactly, we dont want to match every Harrison and every Ford)

# %%
# Some Duration values only had chars, such as 'R'
# Remove them if they dont have any numbers
movies_df = movies_df[movies_df['Duration'].str.contains(r'\d', na=False)]
movies_df = movies_df.reset_index(drop=True)

for i, row in movies_df.iterrows():
  # Turn the stars names into one word, such as HarrisonFord
  actors = str(row['stars'])
  actors = actors.replace(' ', '')
  movies_df.at[i, 'stars'] = actors

# %% [markdown]
# # Create a minutes column for the movie duration
# Will make computations easier later. Turns the string into a minutes number

# %%
for i, row in movies_df.iterrows():
  duration = str(row['Duration'])
  nums = duration.split('h')
  hours = 0
  minutes = 0

  # Have to handle situations such as a movie being less than 1 hour
  if 'm' in nums[0]:
    # Hours stays at the default of 0. Set mins only
    minutes = int(nums[0].replace('m', ''))
  # If 'm' is in the 2nd value, we know there's an hours value we can get
  elif 'm' in nums[1]:
    hours = int(nums[0])
    minutes = int(nums[1].replace('m', ''))
  # Special case such as 2h movie. No mins
  elif 'm' not in nums[1]:
    hours = int(nums[0])

  duration_minutes = hours * 60 + minutes
  movies_df.at[i, 'Duration(mins)'] = duration_minutes

pd.set_option('display.max_rows', None)
movies_df = movies_df.reset_index(drop=True)

# %% [markdown]
# # Create a movie_traits column
# This will have a string containing the movies' genres and actors. Needed to clean up the string a bit to only get the words from it

# %%
def clean_column(column_string):
  """
  Removes and replaces symbols from a string.

  Parameters
  ----------
  column_string : The string to clean.

  Returns
  -------
  The updated string.

  """
  column_string = column_string.replace('[', '')
  column_string = column_string.replace(']', '')
  column_string = column_string.replace("'", '')
  column_string = column_string.replace(',', ' ')
  return column_string

# Clean my column data
stars_list = []
for i, row in movies_df.iterrows():
  genre = row['genres']
  genre = clean_column(genre)
  movies_df.at[i, 'genres'] = genre
  stars = row['stars']
  stars = clean_column(stars)
  movies_df.at[i, 'stars'] = stars

movies_df['movie_traits'] = movies_df['genres'] + ' ' + movies_df['stars']
movies_df.head()
# Out:
#                               Title Duration  Rating  \
# 0  Captain America: Brave New World   1h 58m     5.9
# 1                           Dog Man   1h 29m     6.3
# 2                  One of Them Days   1h 37m     6.6
# 3                         Mickey 17   2h 17m     7.0
# 4                        The Monkey   1h 38m     6.3
#
#                                          description  \
# 0  Sam Wilson, the new Captain America, finds him...
# 1  Dog Man, half dog and half man, he is sworn to...
# 2  When best friends and roommates Dreux and Alys...
# 3  Mickey 17, known as an "expendable," goes on a...
# 4  When twin brothers Bill and Hal find their fat...
#
#                                           Movie Link  \
# 0  https://www.imdb.com/title/tt14513804/?ref_=sr...
# 1  https://www.imdb.com/title/tt10954718/?ref_=sr...
# 2  https://www.imdb.com/title/tt32221196/?ref_=sr...
# 3  https://www.imdb.com/title/tt12299608/?ref_=sr...
# 4  https://www.imdb.com/title/tt27714946/?ref_=sr...
#
#                                                stars  \
# 0  AnthonyMackie HarrisonFord DannyRamirez ShiraH...
# 1  PeteDavidson PoppyLiu LilRelHowery IslaFisher ...
# 2  KekePalmer SZA VanessaBellCalloway LilRelHower...
# 3  RobertPattinson StevenYeun MichaelMonroe Patsy...
# 4  TheoJames TatianaMaslany ChristianConvery "Col...
#
#                                               genres  Duration(mins)  \
# 0  Action Epic  Adventure Epic  Sci-Fi Epic  Supe...           118.0
# 1  Animal Adventure  Computer Animation  Superher...            89.0
# 2                               Buddy Comedy  Comedy            97.0
# 3  Alien Invasion  Dark Comedy  Space Sci-Fi  Adv...           137.0
# 4               Dark Comedy  Splatter Horror  Horror            98.0
#
#                                         movie_traits
# 0  Action Epic  Adventure Epic  Sci-Fi Epic  Supe...
# 1  Animal Adventure  Computer Animation  Superher...
# 2  Buddy Comedy  Comedy KekePalmer SZA VanessaBel...
# 3  Alien Invasion  Dark Comedy  Space Sci-Fi  Adv...
# 4  Dark Comedy  Splatter Horror  Horror TheoJames...

# %% [markdown]
# # Get the users ideal movie duration
# Will create a duration range based on their input. Later on, will remove movie options that are too far out of their target duration range.

# %%
def get_ideal_duration():
  """
  Gets the user input for how long their ideal movie length is.

  Returns
  -------
  The user's ideal movie length. First nuber is hours, second number is minutes.

  """
  # Set the range for how much higher AND lower the target duration will be
  # For instance, say the user enters 1 hour as their ideal duration
  # We want the duration range to be between 25 mins and 1hr 45 mins
  DURATION_RANGE = 45
  while True:
    ideal_duration = input('What\'s your ideal movie length? (Type first number as # of hours, second number as # of minutes. 2 0 for 2 hrs and 0 mins)\n')
    nums = ideal_duration.split()
    if len(nums) != 2:
      print('Please enter 2 numbers')
      continue
    elif int(nums[0]) < 0 or int(nums[0]) > 3:
      print('Please enter a realistic number of hours for a movie (0-3)')
      continue
    elif int(nums[1]) < 0 or int(nums[1]) > 60:
      print('Please enter a number of minutes between 0-60')
      continue
    else:
      hours = int(nums[0])
      minutes = int(nums[1])
      duration_minutes = hours * 60 + minutes
      lower_bound = duration_minutes - DURATION_RANGE
      upper_bound = duration_minutes + DURATION_RANGE
      break
  return lower_bound, upper_bound

# %% [markdown]
# # Get Users Preferences
# Give the user a genre menu and allow them to enter their favorite genres. Then allow them to type in however many favorite actors they want.

# %%
def get_fav_genres():
    """
    Gets the user's favorite movie genres.

    Returns
    -------
    The user's favorite movie genres as a string.

    """
    genres_to_add = input('''Enter the numbers that correspond to genres you like. (For example, you would enter 1 8 17 if you wanted to pick
    Action, Drama and Thriller as your favorites)
    1) Action
    2) Adventure
    3) Animation
    4) Biography
    5) Comedy
    6) Crime
    7) Documentary
    8) Drama
    9) Family
    10) Fantasy
    11) Horror
    12) Musical
    13) Mystery
    14) Romance
    15) Sci-Fi
    16) Sport
    17) Thriller
    18) War
    19) Western
    ''')
    fav_genres = ''
    genres_nums = genres_to_add.split()
    for g in genres_nums:
      if g == '1':
        fav_genres += 'Action '
      elif g == '2':
        fav_genres += 'Adventure '
      elif g == '3':
        fav_genres += 'Animation '
      elif g == '4':
        fav_genres += 'Biography '
      elif g == '5':
        fav_genres += 'Comedy '
      elif g == '6':
        fav_genres += 'Crime '
      elif g == '7':
        fav_genres += 'Documentary '
      elif g == '8':
        fav_genres += 'Drama '
      elif g == '9':
        fav_genres += 'Family '
      elif g == '10':
        fav_genres += 'Fantasy '
      elif g == '11':
        fav_genres += 'Horror '
      elif g == '12':
        fav_genres += 'Musical '
      elif g == '13':
        fav_genres += 'Mystery '
      elif g == '14':
        fav_genres += 'Romance '
      elif g == '15':
        fav_genres += 'Sci-Fi '
      elif g == '16':
        fav_genres += 'Sport '
      elif g == '17':
        fav_genres += 'Thriller '
      elif g == '18':
        fav_genres += 'War '
      elif g == '19':
        fav_genres += 'Western '


    return fav_genres.rstrip()


def get_fav_actors():
  """
  Gets the user 's favorite actors.

  Returns
  -------
  The user's favorite actors as a string.

  """
  actors_string = ''
  while True:
    actor = input('Enter one of your favorite actors names (first and last), or enter Q to quit. '
    'Example input: Harrison Ford\n')
    if actor == 'Q' or actor =='q':
      break
    else:
      actor = actor.replace(' ', '')
      actors_string += actor + ' '
  return actors_string.rstrip()

# %% [markdown]
# # Compute Recommender based on cosine similarity

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

ideal_duration = get_ideal_duration()
lower_bound = ideal_duration[0]
upper_bound = ideal_duration[1]

# Have the df only have movies within our duration range
movies_df = movies_df[(movies_df['Duration(mins)'] >= lower_bound) & (movies_df['Duration(mins)'] <= upper_bound)]

# Get users preferences
fav_genres = get_fav_genres()
fav_actors = get_fav_actors()
user_preferences = fav_genres + ' ' + fav_actors
print(user_preferences)

cosine_sim_list = []
#movie_traits = []
for i, row in movies_df.iterrows():
  traits = row['movie_traits']
  # Convert strings to TF-IDF vectors
  vectorizer = TfidfVectorizer()
  tfidf_matrix = vectorizer.fit_transform([user_preferences, traits])

  # Compute cosine similarity
  cosine_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])
  cosine_sim_list.append(cosine_sim[0][0])
movies_df['cosine_sim'] = cosine_sim_list
movies_df = movies_df.sort_values(by=['cosine_sim'], ascending=False)
movies_df = movies_df.reset_index(drop=True)
movies_df.head(3)
# Out:
# What's your ideal movie length? (Type first number as # of hours, second number as # of minutes. 2 0 for 2 hrs and 0 mins)
# 2 0
# Enter the numbers that correspond to genres you like. (For example, you would enter 1 8 17 if you wanted to pick
#     Action, Drama and Thriller as your favorites)
#     1) Action
#     2) Adventure
#     3) Animation
#     4) Biography
#     5) Comedy
#     6) Crime
#     7) Documentary
#     8) Drama
#     9) Family
#     10) Fantasy
#     11) Horror
#     12) Musical
#     13) Mystery
#     14) Romance
#     15) Sci-Fi
#     16) Sport
#     17) Thriller
#     18) War
#     19) Western
#     1 2 3 4 5
# Enter one of your favorite actors names (first and last), or enter Q to quit. Example input: Harrison Ford
# q
# Action Adventure Animation Biography Comedy
#                              Title Duration  Rating  \
# 0                          Dog Man   1h 29m     6.3
# 1              Plankton: The Movie   1h 27m     5.4
# 2  The Witcher: Sirens of the Deep   1h 31m     6.1
#
#                                          description  \
# 0  Dog Man, half dog and half man, he is sworn to...
# 1  When Karen the Computer decides to take over t...
# 2  Hired to probe seaside village attacks, mutant...
#
#                                           Movie Link  \
# 0  https://www.imdb.com/title/tt10954718/?ref_=sr...
# 1  https://www.imdb.com/title/tt32560777/?ref_=sr...
# 2  https://www.imdb.com/title/tt15495150/?ref_=sr...
#
#                                                stars  \
# 0  PeteDavidson PoppyLiu LilRelHowery IslaFisher ...
# 1  Mr.Lawrence JillTalley TomKenny BillFagerbakke...
# 2  DougCockle JoeyBatey AnyaChalotra ChristinaWre...
#
#                                               genres  Duration(mins)  \
# 0  Animal Adventure  Computer Animation  Superher...            89.0
# 1  Computer Animation  Adventure  Animation  Come...            87.0
# 2  Adult Animation  Anime  Dark Fantasy  Action  ...            91.0
#
#                                         movie_traits  cosine_sim
# 0  Animal Adventure  Computer Animation  Superher...    0.380536
# 1  Computer Animation  Adventure  Animation  Come...    0.254179
# 2  Adult Animation  Anime  Dark Fantasy  Action  ...    0.229957

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 7.0 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.14.1

# %% [markdown]
# # Time to nicely format and display the top 3 movie matches

# %%
from os import link
top_three_movie_titles = []
top_three_movie_durations = []
top_three_movie_ratings = []
top_three_movie_descriptions = []
top_three_movie_links = []
for i in range(3):
  top_three_movie_titles.append(movies_df.iloc[i]['Title'])
  top_three_movie_durations.append(movies_df.iloc[i]['Duration'])
  top_three_movie_ratings.append(movies_df.iloc[i]['Rating'])
  top_three_movie_descriptions.append(movies_df.iloc[i]['description'])
  top_three_movie_links.append(movies_df.iloc[i]['Movie Link'])


from bs4 import BeautifulSoup
import requests
import cv2
from google.colab.patches import cv2_imshow
import urllib.request
import numpy as np
import textwrap
import emoji

print('\033[1mYOUR TOP 3 MOVIE MATCHES OF 2025:\033[0m \n')

for i, title in enumerate(top_three_movie_titles):
  movie = title.strip()
  movie = movie.lower()
  movie = movie.replace(' ', '_')
  movie = re.sub(r'[^\w]', '', movie)

  media_tag = '#media-info'

  test_url = f"https://www.rottentomatoes.com/m/{movie}{media_tag}"
  url = ""

  page = requests.get(test_url).text
  doc = BeautifulSoup(page, 'html.parser')

  found_movie_url = False
  release_year = doc.find_all(attrs={'data-qa':'item-value'})
  # Big problem when there's a movie title that overlaps with a movie that was
  # released a long time ago. For instance /sinners goes to a 1989 movie
  # Want the 2025 one
  # Search the media-info text for the release year.
  # If 2025 is found, we have the correct movie URL
  # If 2025 isnt found, we have a url with an old movie. Need _2025 added to URL
  release_year_exists = False
  find_year = doc.find_all(attrs={'class':'key', 'data-qa':'item-label'})
  for y in find_year:
    text = y.text
    text = text.lower()
    phrase = 'release date'
    if phrase in text:
        release_year_exists = True

  if release_year_exists:
    found_movie_url = False
    release_year = doc.find_all(attrs={'data-qa':'item-value'})
    for item in release_year:
      target_year = '2025'
      text = item.text.strip()
      if target_year in text:
          found_movie_url = True

  if found_movie_url:
      url = f"https://www.rottentomatoes.com/m/{movie}"
  else:
      url = f"https://www.rottentomatoes.com/m/{movie}_2025"


  # Print the movie title and ranking for the user
  title = top_three_movie_titles[i]
  print(f'\033[1m{i + 1})\033[0m \033[4m{title}\033[0m:')

  # Try and find the movie cover pic fro Rotten Tomatoes

  page = requests.get(url).text
  doc = BeautifulSoup(page, 'html.parser')
  movie_pic = doc.find(attrs={'alt':'poster image'})
  try:
    movie_pic = movie_pic['src']

    req = urllib.request.urlopen(movie_pic)
    arr = np.asarray(bytearray(req.read()), dtype=np.uint8)
    img = cv2.imdecode(arr, -1) # 'Load it as it is'
    # Save the image
    cv2.imwrite('Movie.png', img)
    # Display the image
    display_img = cv2.imread('Movie.png', img)
    cv2_imshow(display_img)
  except:
    print('Movie pic not found')

  duration = top_three_movie_durations[i]
  description = top_three_movie_descriptions[i]
  width = 65
  wrapped_text = textwrap.fill(description, width)
  rating = top_three_movie_ratings[i]
  link = top_three_movie_links[i]
  print(f'\033[1mDuration:\033[0m {duration}')
  print()
  print(f'\033[1mDescription:\033[0m {wrapped_text}')
  print()
  stars = emoji.emojize(':star:')
  print(f'\033[1mRating:\033[0m {rating}{stars}s')
  print()
  print(f'\033[1mLink:\033[0m {link}')
  print('\n')
# Out:
# YOUR TOP 3 MOVIE MATCHES OF 2025:
#
# 1) Dog Man:
# <PIL.Image.Image image mode=RGB size=206x305>
# Duration: 1h 29m
#
# Description: Dog Man, half dog and half man, he is sworn to protect and serve
# as he doggedly pursues the feline supervillain Petey the Cat.
#
# Rating: 6.3⭐s
#
# Link: https://www.imdb.com/title/tt10954718/?ref_=sr_i_2
#
#
# 2) Plankton: The Movie:
# <PIL.Image.Image image mode=RGB size=206x305>
# Duration: 1h 27m
#
# Description: When Karen the Computer decides to take over the world, it's up
# to Plankton to stop her - with a little help from SpongeBob and
# the Gal Pals (Pearl, Sandy, and Mrs. Puff).
#
# Rating: 5.4⭐s
#
# Link: https://www.imdb.com/title/tt32560777/?ref_=sr_i_104
#
#
# 3) The Witcher: Sirens of the Deep:
# <PIL.Image.Image image mode=RGB size=206x305>
# Duration: 1h 31m
#
# Description: Hired to probe seaside village attacks, mutant monster hunter
# Geralt unravels an age-old conflict between humans and sea people
# that threatens war between kingdoms. Aided by allies, he must
# solve the mystery before hostilities escalate.
#
# Rating: 6.1⭐s
#
# Link: https://www.imdb.com/title/tt15495150/?ref_=sr_i_162
